# %%
import pandas as pd
import numpy as np
import utils
import pyarrow
from datetime import datetime, timedelta

READ_PARQUET = True
pd.set_option('display.max_columns', None)

# %%
import pickle
import calendar

# %%
import importlib
utils = importlib.reload(utils)  # reloads the utils module without restarting kernel

# %%
if READ_PARQUET:
    print("Reading parquet.")
    log = utils.load_parquet()
else:
    print("Reading csv and savings as parquet.")
    df = utils.load_csv()
    utils.save_parquet(df)
# Out:
# Reading parquet.

# %%
from copy import deepcopy
# drop uncomplete cases (2017 mostly) and thus do not have a complete label

#cases_df = deepcopy(df.loc[df['Complete Timestamp'].dt.year < 2017])
df = deepcopy(log)

# %% [markdown]
# ### Rename changed process and doctype names

# %%
df = df.replace({'Department control parcels': 'Geo parcel document'}, regex=True)
df = df.replace({'Parcel document': 'Geo parcel document'}, regex=True)

# %% [markdown]
# ### Adding  Sub Process

# %%
def column_sub_process(data):
    data['Sub_Process'] = data['Activity'].apply(lambda x: x.split('-', 2)[:2])
    data['Sub_Process'] = [', '.join(map(str, l)) for l in data['Sub_Process']]
    return data

# %%
df = column_sub_process(df)

# %% [markdown]
# ### Adding start date and end date

# %%
dfc = df.groupby('Case ID')['Complete Timestamp']
df = df.assign(min=dfc.transform(min), max=dfc.transform(max)).rename(columns={'min':'StartDate', 'max' : 'EndDate'})

# %%
df = df.rename(columns= {'max': 'EndDate', 'min': 'StartDate'})

# %% [markdown]
# ### Adding total duration

# %%
df['EndDate']= pd.to_datetime(df['EndDate'])
df['StartDate']= pd.to_datetime(df['StartDate'])
df['Total_Duration'] = df['EndDate'] - df['StartDate']
df.Total_Duration = df['Total_Duration'].dt.days

# %% [markdown]
# ### Adding time passed till then

# %%
df['Complete Timestamp'] =  pd.to_datetime(df['Complete Timestamp'])
df['TimePassed'] = df['Complete Timestamp'] - df['StartDate']
df.TimePassed = df['TimePassed'].dt.days

# %% [markdown]
# ### Adding eventcounter

# %%
df['event'] = 1
df['eventcounter'] = df.groupby(['Case ID'])['event'].apply(lambda x: x.cumsum())

# %% [markdown]
# ### Adding cumulative success

# %%
df['success'] = df['success'].astype(int)
df['cum_success'] = df.groupby(['Case ID'])['success'].apply(lambda x: x.cumsum())
df['succes_rate'] = df['cum_success']/df['eventcounter']

# %% [markdown]
# ### Adding activity counter

# %%
df['cum_activity'] = df.groupby(['Case ID', 'activity'])['event'].apply(lambda x: x.cumsum())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-a88d7bd882a3> in <module>
# ----> 1 df['cum_activity'] = df.groupby(['Case ID', 'activity'])['event'].apply(lambda x: x.cumsum())
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     222     )
#     223     def apply(self, func, *args, **kwargs):
# --> 224         return super().apply(func, *args, **kwargs)
#     225
#     226     @Substitution(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734         with option_context("mode.chained_assignment", None):
#     735             try:
# --> 736                 result = self._python_apply_general(f)
#     737             except TypeError:
#     738                 # gh-20949
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750
#     751     def _python_apply_general(self, f):
# --> 752         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     753
#     754         return self._wrap_applied_output(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     204             # group might be modified
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#     208                 mutated = True
#
# <ipython-input-16-a88d7bd882a3> in <lambda>(x)
# ----> 1 df['cum_activity'] = df.groupby(['Case ID', 'activity'])['event'].apply(lambda x: x.cumsum())
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in cum_func(self, axis, skipna, *args, **kwargs)
#   11327             return result.T if hasattr(result, "T") else result
#   11328
# > 11329         result = self._data.apply(na_accum_func)
#   11330
#   11331         d = self._construct_axes_dict()
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     438
#     439             if callable(f):
# --> 440                 applied = b.apply(f, **kwargs)
#     441             else:
#     442                 applied = getattr(b, f)(**kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in apply(self, func, **kwargs)
#     390             result = func(self.values, **kwargs)
#     391
# --> 392         if is_extension_array_dtype(result) and result.ndim > 1:
#     393             # if we get a 2D ExtensionArray, we need to split it into 1D pieces
#     394             nbs = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\common.py in is_extension_array_dtype(arr_or_dtype)
#    1609     """
#    1610     dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
# -> 1611     return isinstance(dtype, ExtensionDtype) or registry.find(dtype) is not None
#    1612
#    1613
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py in find(self, dtype)
#      85         return the first matching dtype, otherwise return None
#      86         """
# ---> 87         if not isinstance(dtype, str):
#      88             dtype_type = dtype
#      89             if not isinstance(dtype, type):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Adding Sub process counter

# %%
df['cum_subprocess'] = df.groupby(['Case ID', 'Sub_Process'])['event'].apply(lambda x: x.cumsum())

# %%
df.loc[df['Case ID'] == '8b99873a6136cfa6']

# %% [markdown]
# ### Add  time between concurrent activities

# %%
df['Sub_Process'].nunique()

# %%
df['Timelag'] =df.groupby('Case ID')['Complete Timestamp'].diff()
df.Timelag = df['Timelag'].dt.days
df.Timelag = df['Timelag'].fillna(0)

# %% [markdown]
# ### Add max, min, mean time between activities for a Case ID until that point
# #### didn't include min time lag because always 0

# %%
df['Max_lag'] = df.groupby(['Case ID'])['Timelag'].apply(lambda x: x.cummax())

# %%
df['Avg_lag'] = df.groupby(['Case ID'])['Timelag'].apply(lambda x: x.shift().expanding().mean())
df['Avg_lag'] = df['Avg_lag'].fillna(0)

# %% [markdown]
# # Drop nog de nietszeggende columns

# %%
df

# %%
del df['event']

# %%
df

# %% [markdown]
# ### T0 features

# %%
df = pickle.load(open('C:/Users/nlsvee/Documents/JADS Y2/PROM/Assignment 2/process-mining-assignment-2/dataset/final_input_for_counters', 'rb'))

# %%
df
# Out:
#                   Case ID                                         Activity  \
# 0        8b99873a6136cfa6      Payment application-Application-mail income
# 1        8b99873a6136cfa6       Payment application-Application-mail valid
# 2        8b99873a6136cfa6          Entitlement application-Main-mail valid
# 3        8b99873a6136cfa6          Entitlement application-Main-mail valid
# 4        8b99873a6136cfa6              Geo parcel document-Main-initialize
# ...                   ...                                              ...
# 2514261  ad5dfa0b929735be           Payment application-Application-decide
# 2514262  ad5dfa0b929735be    Payment application-Application-begin payment
# 2514263  ad5dfa0b929735be  Payment application-Application-insert document
# 2514264  ad5dfa0b929735be  Payment application-Application-insert document
# 2514265  ad5dfa0b929735be   Payment application-Application-finish payment
#
#                        Resource      Complete Timestamp        Variant  \
# 0                         0;n/a 2015-05-08 00:00:00.000   Variant 1832
# 1                         0;n/a 2015-05-08 00:00:00.000   Variant 1832
# 2                         0;n/a 2015-05-08 00:00:00.000   Variant 1832
# 3                         0;n/a 2015-05-08 00:00:00.000   Variant 1832
# 4                        fb5fa8 2015-06-10 11:16:28.000   Variant 1832
# ...                         ...                     ...            ...
# 2514261                  155add 2017-12-11 10:26:39.692  Variant 28923
# 2514262                    DP-Z 2017-12-15 16:00:12.252  Variant 28923
# 2514263  Notification automaton 2017-12-15 19:19:04.499  Variant 28923
# 2514264  Notification automaton 2017-12-20 09:02:30.380  Variant 28923
# 2514265                    DP-Z 2018-01-05 14:45:52.100  Variant 28923
#
#          Variant index  (case) amount_applied0  (case) amount_applied1  \
# 0                 1832                  960.35                     NaN
# 1                 1832                  960.35                     NaN
# 2                 1832                  960.35                     NaN
# 3                 1832                  960.35                     NaN
# 4                 1832                  960.35                     NaN
# ...                ...                     ...                     ...
# 2514261          28923                 5117.97                     NaN
# 2514262          28923                 5117.97                     NaN
# 2514263          28923                 5117.97                     NaN
# 2514264          28923                 5117.97                     NaN
# 2514265          28923                 5117.97                     NaN
#
#          (case) amount_applied2  (case) amount_applied3  (case) applicant  \
# 0                           NaN                     NaN  b3b1bafcf8a5c359
# 1                           NaN                     NaN  b3b1bafcf8a5c359
# 2                           NaN                     NaN  b3b1bafcf8a5c359
# 3                           NaN                     NaN  b3b1bafcf8a5c359
# 4                           NaN                     NaN  b3b1bafcf8a5c359
# ...                         ...                     ...               ...
# 2514261                     NaN                     NaN  3a96cda3a6b0f35f
# 2514262                     NaN                     NaN  3a96cda3a6b0f35f
# 2514263                     NaN                     NaN  3a96cda3a6b0f35f
# 2514264                     NaN                     NaN  3a96cda3a6b0f35f
# 2514265                     NaN                     NaN  3a96cda3a6b0f35f
#
#         (case) application  (case) area  (case) basic payment  \
# 0         8b99873a6136cfa6       2.6994                  True
# 1         8b99873a6136cfa6       2.6994                  True
# 2         8b99873a6136cfa6       2.6994                  True
# 3         8b99873a6136cfa6       2.6994                  True
# 4         8b99873a6136cfa6       2.6994                  True
# ...                    ...          ...                   ...
# 2514261   ad5dfa0b929735be      15.2806                  True
# 2514262   ad5dfa0b929735be      15.2806                  True
# 2514263   ad5dfa0b929735be      15.2806                  True
# 2514264   ad5dfa0b929735be      15.2806                  True
# 2514265   ad5dfa0b929735be      15.2806                  True
#
#          (case) cross_compliance (case) department  (case) greening  \
# 0                            0.0                e7             True
# 1                            0.0                e7             True
# 2                            0.0                e7             True
# 3                            0.0                e7             True
# 4                            0.0                e7             True
# ...                          ...               ...              ...
# 2514261                      0.0                6b             True
# 2514262                      0.0                6b             True
# 2514263                      0.0                6b             True
# 2514264                      0.0                6b             True
# 2514265                      0.0                6b             True
#
#          (case) number_parcels  (case) payment_actual0  \
# 0                            3                  960.35
# 1                            3                  960.35
# 2                            3                  960.35
# 3                            3                  960.35
# 4                            3                  960.35
# ...                        ...                     ...
# 2514261                      6                 5116.99
# 2514262                      6                 5116.99
# 2514263                      6                 5116.99
# 2514264                      6                 5116.99
# 2514265                      6                 5116.99
#
#          (case) payment_actual1  (case) payment_actual2  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 2514261                     NaN                     NaN
# 2514262                     NaN                     NaN
# 2514263                     NaN                     NaN
# 2514264                     NaN                     NaN
# 2514265                     NaN                     NaN
#
#          (case) payment_actual3  (case) penalty_ABP  (case) penalty_AGP  \
# 0                           NaN               False               False
# 1                           NaN               False               False
# 2                           NaN               False               False
# 3                           NaN               False               False
# 4                           NaN               False               False
# ...                         ...                 ...                 ...
# 2514261                     NaN               False               False
# 2514262                     NaN               False               False
# 2514263                     NaN               False               False
# 2514264                     NaN               False               False
# 2514265                     NaN               False               False
#
#          (case) penalty_AJLP  (case) penalty_AUVP  (case) penalty_AVBP  \
# 0                      False                False                False
# 1                      False                False                False
# 2                      False                False                False
# 3                      False                False                False
# 4                      False                False                False
# ...                      ...                  ...                  ...
# 2514261                False                False                False
# 2514262                False                False                False
# 2514263                False                False                False
# 2514264                False                False                False
# 2514265                False                False                False
#
#          (case) penalty_AVGP  (case) penalty_AVJLP  (case) penalty_AVUVP  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
# ...                      ...                   ...                   ...
# 2514261                False                 False                 False
# 2514262                False                 False                 False
# 2514263                False                 False                 False
# 2514264                False                 False                 False
# 2514265                False                 False                 False
#
#          (case) penalty_B16  (case) penalty_B2  (case) penalty_B3  \
# 0                     False              False              False
# 1                     False              False              False
# 2                     False              False              False
# 3                     False              False              False
# 4                     False              False              False
# ...                     ...                ...                ...
# 2514261               False              False              False
# 2514262               False              False              False
# 2514263               False              False              False
# 2514264               False              False              False
# 2514265               False              False              False
#
#          (case) penalty_B4  (case) penalty_B5  (case) penalty_B5F  \
# 0                    False              False               False
# 1                    False              False               False
# 2                    False              False               False
# 3                    False              False               False
# 4                    False              False               False
# ...                    ...                ...                 ...
# 2514261              False              False               False
# 2514262              False              False               False
# 2514263              False              False               False
# 2514264              False              False               False
# 2514265              False              False               False
#
#          (case) penalty_B6  (case) penalty_BGK  (case) penalty_BGKV  \
# 0                    False               False                False
# 1                    False               False                False
# 2                    False               False                False
# 3                    False               False                False
# 4                    False               False                False
# ...                    ...                 ...                  ...
# 2514261              False               False                False
# 2514262              False               False                False
# 2514263              False               False                False
# 2514264              False               False                False
# 2514265              False               False                False
#
#          (case) penalty_BGP  (case) penalty_C16  (case) penalty_C4  \
# 0                     False               False              False
# 1                     False               False              False
# 2                     False               False              False
# 3                     False               False              False
# 4                     False               False              False
# ...                     ...                 ...                ...
# 2514261               False               False              False
# 2514262               False               False              False
# 2514263               False               False              False
# 2514264               False               False              False
# 2514265               False               False              False
#
#          (case) penalty_C9  (case) penalty_CC  (case) penalty_GP1  \
# 0                    False              False               False
# 1                    False              False               False
# 2                    False              False               False
# 3                    False              False               False
# 4                    False              False               False
# ...                    ...                ...                 ...
# 2514261              False              False               False
# 2514262              False              False               False
# 2514263              False              False               False
# 2514264              False              False               False
# 2514265              False              False               False
#
#          (case) penalty_JLP1  (case) penalty_JLP2  (case) penalty_JLP3  \
# 0                      False                False                False
# 1                      False                False                False
# 2                      False                False                False
# 3                      False                False                False
# 4                      False                False                False
# ...                      ...                  ...                  ...
# 2514261                False                False                False
# 2514262                False                False                False
# 2514263                False                False                False
# 2514264                False                False                False
# 2514265                False                False                False
#
#          (case) penalty_JLP5  (case) penalty_JLP6  (case) penalty_JLP7  \
# 0                      False                False                False
# 1                      False                False                False
# 2                      False                False                False
# 3                      False                False                False
# 4                      False                False                False
# ...                      ...                  ...                  ...
# 2514261                False                False                False
# 2514262                False                False                False
# 2514263                False                False                False
# 2514264                False                False                False
# 2514265                False                False                False
#
#          (case) penalty_V5  (case) penalty_amount0  (case) penalty_amount1  \
# 0                    False                     0.0                     NaN
# 1                    False                     0.0                     NaN
# 2                    False                     0.0                     NaN
# 3                    False                     0.0                     NaN
# 4                    False                     0.0                     NaN
# ...                    ...                     ...                     ...
# 2514261              False                     0.0                     NaN
# 2514262              False                     0.0                     NaN
# 2514263              False                     0.0                     NaN
# 2514264              False                     0.0                     NaN
# 2514265              False                     0.0                     NaN
#
#          (case) penalty_amount2  (case) penalty_amount3  (case) program-id  \
# 0                           NaN                     NaN                215
# 1                           NaN                     NaN                215
# 2                           NaN                     NaN                215
# 3                           NaN                     NaN                215
# 4                           NaN                     NaN                215
# ...                         ...                     ...                ...
# 2514261                     NaN                     NaN                215
# 2514262                     NaN                     NaN                215
# 2514263                     NaN                     NaN                215
# 2514264                     NaN                     NaN                215
# 2514265                     NaN                     NaN                215
#
#          (case) redistribution  (case) rejected  (case) risk_factor  \
# 0                         True            False                 1.0
# 1                         True            False                 1.0
# 2                         True            False                 1.0
# 3                         True            False                 1.0
# 4                         True            False                 1.0
# ...                        ...              ...                 ...
# 2514261                   True            False                 1.0
# 2514262                   True            False                 1.0
# 2514263                   True            False                 1.0
# 2514264                   True            False                 1.0
# 2514265                   True            False                 1.0
#
#          (case) selected_manually  (case) selected_random  \
# 0                           False                   False
# 1                           False                   False
# 2                           False                   False
# 3                           False                   False
# 4                           False                   False
# ...                           ...                     ...
# 2514261                     False                   False
# 2514262                     False                   False
# 2514263                     False                   False
# 2514264                     False                   False
# 2514265                     False                   False
#
#          (case) selected_risk  (case) small farmer  (case) year  \
# 0                       False                 True         2015
# 1                       False                 True         2015
# 2                       False                 True         2015
# 3                       False                 True         2015
# 4                       False                 True         2015
# ...                       ...                  ...          ...
# 2514261                 False                False         2017
# 2514262                 False                False         2017
# 2514263                 False                False         2017
# 2514264                 False                False         2017
# 2514265                 False                False         2017
#
#          (case) young farmer         activity     concept:name  \
# 0                      False      mail income      mail income
# 1                      False       mail valid       mail valid
# 2                      False       mail valid       mail valid
# 3                      False       mail valid       mail valid
# 4                      False       initialize       initialize
# ...                      ...              ...              ...
# 2514261                False           decide           decide
# 2514262                False    begin payment    begin payment
# 2514263                False  insert document  insert document
# 2514264                False  insert document  insert document
# 2514265                False   finish payment   finish payment
#
#                      docid                  doctype       eventid  \
# 0       -18008611495569447      Payment application           NaN
# 1       -18008611495569447      Payment application           NaN
# 2       -18008615298673397  Entitlement application           NaN
# 3       -18008615298673397  Entitlement application           NaN
# 4       -72051858488795160      Geo parcel document -7.205186e+16
# ...                    ...                      ...           ...
# 2514261 -54037160734808716      Payment application -9.006594e+16
# 2514262 -54037160734808716      Payment application -9.006594e+16
# 2514263 -54037160734808716      Payment application -9.006594e+16
# 2514264 -54037160734808716      Payment application -1.260947e+17
# 2514265 -54037160734808716      Payment application -1.800834e+16
#
#         lifecycle:transition                        note   subprocess  \
# 0                   complete                        none  Application
# 1                   complete                        none  Application
# 2                   complete                        none         Main
# 3                   complete                        none         Main
# 4                   complete                        none         Main
# ...                      ...                         ...          ...
# 2514261             complete                   automatic  Application
# 2514262             complete    automatic during payment  Application
# 2514263             complete  notification for applicant  Application
# 2514264             complete  notification for applicant  Application
# 2514265             complete    automatic during payment  Application
#
#          success                       Sub_Process  StartDate  \
# 0              1  Payment application, Application 2015-05-08
# 1              1  Payment application, Application 2015-05-08
# 2              1     Entitlement application, Main 2015-05-08
# 3              1     Entitlement application, Main 2015-05-08
# 4              1         Geo parcel document, Main 2015-05-08
# ...          ...                               ...        ...
# 2514261        1  Payment application, Application 2017-04-13
# 2514262        1  Payment application, Application 2017-04-13
# 2514263        1  Payment application, Application 2017-04-13
# 2514264        0  Payment application, Application 2017-04-13
# 2514265        1  Payment application, Application 2017-04-13
#
#                         EndDate  Total_Duration  TimePassed  eventcounter  \
# 0       2016-02-18 07:56:22.774             286           0             1
# 1       2016-02-18 07:56:22.774             286           0             2
# 2       2016-02-18 07:56:22.774             286           0             3
# 3       2016-02-18 07:56:22.774             286           0             4
# 4       2016-02-18 07:56:22.774             286          33             5
# ...                         ...             ...         ...           ...
# 2514261 2018-01-05 14:45:52.100             267         242            59
# 2514262 2018-01-05 14:45:52.100             267         246            60
# 2514263 2018-01-05 14:45:52.100             267         246            61
# 2514264 2018-01-05 14:45:52.100             267         251            62
# 2514265 2018-01-05 14:45:52.100             267         267            63
#
#          cum_success  succes_rate  cum_activity  cum_subprocess  Timelag  \
# 0                  1     1.000000             1               1      0.0
# 1                  2     1.000000             1               2      0.0
# 2                  3     1.000000             2               1      0.0
# 3                  4     1.000000             3               2      0.0
# 4                  5     1.000000             1               1     33.0
# ...              ...          ...           ...             ...      ...
# 2514261           59     1.000000             1              16      2.0
# 2514262           60     1.000000             1              17      4.0
# 2514263           61     1.000000             2              18      0.0
# 2514264           61     0.983871             3              19      4.0
# 2514265           62     0.984127             1              20     16.0
#
#          Max_lag   Avg_lag
# 0            0.0  0.000000
# 1            0.0  0.000000
# 2            0.0  0.000000
# 3            0.0  0.000000
# 4           33.0  0.000000
# ...          ...       ...
# 2514261     75.0  4.017241
# 2514262     75.0  3.983051
# 2514263     75.0  3.983333
# 2514264     75.0  3.918033
# 2514265     75.0  3.919355
#
# [2514266 rows x 88 columns]

# %%
df['avg_amount_applied0_per_parcel'] = df['(case) amount_applied0'] / df['(case) number_parcels']

# %%
df['avg_amount_applied0_per_area'] = df['(case) amount_applied0'] / df['(case) area']

# %%
df['avg_area_per_parcel'] = df['(case) area'] / df['(case) number_parcels']

# %%
df['StartMonth'] = pd.DatetimeIndex(df['StartDate']).month
startmonth = df['StartMonth'].to_list()


monthlist = []
for i in startmonth:
    monthlist.append(calendar.month_name[i])
    
df['StartMonth'] = monthlist

#df['Month'] = df['Month'].apply(lambda x: calendar.month_abbr[x])

# %%
df
# Out:
#                   Case ID                                         Activity  \
# 0        8b99873a6136cfa6      Payment application-Application-mail income
# 1        8b99873a6136cfa6       Payment application-Application-mail valid
# 2        8b99873a6136cfa6          Entitlement application-Main-mail valid
# 3        8b99873a6136cfa6          Entitlement application-Main-mail valid
# 4        8b99873a6136cfa6              Geo parcel document-Main-initialize
# ...                   ...                                              ...
# 2514261  ad5dfa0b929735be           Payment application-Application-decide
# 2514262  ad5dfa0b929735be    Payment application-Application-begin payment
# 2514263  ad5dfa0b929735be  Payment application-Application-insert document
# 2514264  ad5dfa0b929735be  Payment application-Application-insert document
# 2514265  ad5dfa0b929735be   Payment application-Application-finish payment
#
#                        Resource      Complete Timestamp        Variant  \
# 0                         0;n/a 2015-05-08 00:00:00.000   Variant 1832
# 1                         0;n/a 2015-05-08 00:00:00.000   Variant 1832
# 2                         0;n/a 2015-05-08 00:00:00.000   Variant 1832
# 3                         0;n/a 2015-05-08 00:00:00.000   Variant 1832
# 4                        fb5fa8 2015-06-10 11:16:28.000   Variant 1832
# ...                         ...                     ...            ...
# 2514261                  155add 2017-12-11 10:26:39.692  Variant 28923
# 2514262                    DP-Z 2017-12-15 16:00:12.252  Variant 28923
# 2514263  Notification automaton 2017-12-15 19:19:04.499  Variant 28923
# 2514264  Notification automaton 2017-12-20 09:02:30.380  Variant 28923
# 2514265                    DP-Z 2018-01-05 14:45:52.100  Variant 28923
#
#          Variant index  (case) amount_applied0  (case) amount_applied1  \
# 0                 1832                  960.35                     NaN
# 1                 1832                  960.35                     NaN
# 2                 1832                  960.35                     NaN
# 3                 1832                  960.35                     NaN
# 4                 1832                  960.35                     NaN
# ...                ...                     ...                     ...
# 2514261          28923                 5117.97                     NaN
# 2514262          28923                 5117.97                     NaN
# 2514263          28923                 5117.97                     NaN
# 2514264          28923                 5117.97                     NaN
# 2514265          28923                 5117.97                     NaN
#
#          (case) amount_applied2  (case) amount_applied3  (case) applicant  \
# 0                           NaN                     NaN  b3b1bafcf8a5c359
# 1                           NaN                     NaN  b3b1bafcf8a5c359
# 2                           NaN                     NaN  b3b1bafcf8a5c359
# 3                           NaN                     NaN  b3b1bafcf8a5c359
# 4                           NaN                     NaN  b3b1bafcf8a5c359
# ...                         ...                     ...               ...
# 2514261                     NaN                     NaN  3a96cda3a6b0f35f
# 2514262                     NaN                     NaN  3a96cda3a6b0f35f
# 2514263                     NaN                     NaN  3a96cda3a6b0f35f
# 2514264                     NaN                     NaN  3a96cda3a6b0f35f
# 2514265                     NaN                     NaN  3a96cda3a6b0f35f
#
#         (case) application  (case) area  (case) basic payment  \
# 0         8b99873a6136cfa6       2.6994                  True
# 1         8b99873a6136cfa6       2.6994                  True
# 2         8b99873a6136cfa6       2.6994                  True
# 3         8b99873a6136cfa6       2.6994                  True
# 4         8b99873a6136cfa6       2.6994                  True
# ...                    ...          ...                   ...
# 2514261   ad5dfa0b929735be      15.2806                  True
# 2514262   ad5dfa0b929735be      15.2806                  True
# 2514263   ad5dfa0b929735be      15.2806                  True
# 2514264   ad5dfa0b929735be      15.2806                  True
# 2514265   ad5dfa0b929735be      15.2806                  True
#
#          (case) cross_compliance (case) department  (case) greening  \
# 0                            0.0                e7             True
# 1                            0.0                e7             True
# 2                            0.0                e7             True
# 3                            0.0                e7             True
# 4                            0.0                e7             True
# ...                          ...               ...              ...
# 2514261                      0.0                6b             True
# 2514262                      0.0                6b             True
# 2514263                      0.0                6b             True
# 2514264                      0.0                6b             True
# 2514265                      0.0                6b             True
#
#          (case) number_parcels  (case) payment_actual0  \
# 0                            3                  960.35
# 1                            3                  960.35
# 2                            3                  960.35
# 3                            3                  960.35
# 4                            3                  960.35
# ...                        ...                     ...
# 2514261                      6                 5116.99
# 2514262                      6                 5116.99
# 2514263                      6                 5116.99
# 2514264                      6                 5116.99
# 2514265                      6                 5116.99
#
#          (case) payment_actual1  (case) payment_actual2  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 2514261                     NaN                     NaN
# 2514262                     NaN                     NaN
# 2514263                     NaN                     NaN
# 2514264                     NaN                     NaN
# 2514265                     NaN                     NaN
#
#          (case) payment_actual3  (case) penalty_ABP  (case) penalty_AGP  \
# 0                           NaN               False               False
# 1                           NaN               False               False
# 2                           NaN               False               False
# 3                           NaN               False               False
# 4                           NaN               False               False
# ...                         ...                 ...                 ...
# 2514261                     NaN               False               False
# 2514262                     NaN               False               False
# 2514263                     NaN               False               False
# 2514264                     NaN               False               False
# 2514265                     NaN               False               False
#
#          (case) penalty_AJLP  (case) penalty_AUVP  (case) penalty_AVBP  \
# 0                      False                False                False
# 1                      False                False                False
# 2                      False                False                False
# 3                      False                False                False
# 4                      False                False                False
# ...                      ...                  ...                  ...
# 2514261                False                False                False
# 2514262                False                False                False
# 2514263                False                False                False
# 2514264                False                False                False
# 2514265                False                False                False
#
#          (case) penalty_AVGP  (case) penalty_AVJLP  (case) penalty_AVUVP  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
# ...                      ...                   ...                   ...
# 2514261                False                 False                 False
# 2514262                False                 False                 False
# 2514263                False                 False                 False
# 2514264                False                 False                 False
# 2514265                False                 False                 False
#
#          (case) penalty_B16  (case) penalty_B2  (case) penalty_B3  \
# 0                     False              False              False
# 1                     False              False              False
# 2                     False              False              False
# 3                     False              False              False
# 4                     False              False              False
# ...                     ...                ...                ...
# 2514261               False              False              False
# 2514262               False              False              False
# 2514263               False              False              False
# 2514264               False              False              False
# 2514265               False              False              False
#
#          (case) penalty_B4  (case) penalty_B5  (case) penalty_B5F  \
# 0                    False              False               False
# 1                    False              False               False
# 2                    False              False               False
# 3                    False              False               False
# 4                    False              False               False
# ...                    ...                ...                 ...
# 2514261              False              False               False
# 2514262              False              False               False
# 2514263              False              False               False
# 2514264              False              False               False
# 2514265              False              False               False
#
#          (case) penalty_B6  (case) penalty_BGK  (case) penalty_BGKV  \
# 0                    False               False                False
# 1                    False               False                False
# 2                    False               False                False
# 3                    False               False                False
# 4                    False               False                False
# ...                    ...                 ...                  ...
# 2514261              False               False                False
# 2514262              False               False                False
# 2514263              False               False                False
# 2514264              False               False                False
# 2514265              False               False                False
#
#          (case) penalty_BGP  (case) penalty_C16  (case) penalty_C4  \
# 0                     False               False              False
# 1                     False               False              False
# 2                     False               False              False
# 3                     False               False              False
# 4                     False               False              False
# ...                     ...                 ...                ...
# 2514261               False               False              False
# 2514262               False               False              False
# 2514263               False               False              False
# 2514264               False               False              False
# 2514265               False               False              False
#
#          (case) penalty_C9  (case) penalty_CC  (case) penalty_GP1  \
# 0                    False              False               False
# 1                    False              False               False
# 2                    False              False               False
# 3                    False              False               False
# 4                    False              False               False
# ...                    ...                ...                 ...
# 2514261              False              False               False
# 2514262              False              False               False
# 2514263              False              False               False
# 2514264              False              False               False
# 2514265              False              False               False
#
#          (case) penalty_JLP1  (case) penalty_JLP2  (case) penalty_JLP3  \
# 0                      False                False                False
# 1                      False                False                False
# 2                      False                False                False
# 3                      False                False                False
# 4                      False                False                False
# ...                      ...                  ...                  ...
# 2514261                False                False                False
# 2514262                False                False                False
# 2514263                False                False                False
# 2514264                False                False                False
# 2514265                False                False                False
#
#          (case) penalty_JLP5  (case) penalty_JLP6  (case) penalty_JLP7  \
# 0                      False                False                False
# 1                      False                False                False
# 2                      False                False                False
# 3                      False                False                False
# 4                      False                False                False
# ...                      ...                  ...                  ...
# 2514261                False                False                False
# 2514262                False                False                False
# 2514263                False                False                False
# 2514264                False                False                False
# 2514265                False                False                False
#
#          (case) penalty_V5  (case) penalty_amount0  (case) penalty_amount1  \
# 0                    False                     0.0                     NaN
# 1                    False                     0.0                     NaN
# 2                    False                     0.0                     NaN
# 3                    False                     0.0                     NaN
# 4                    False                     0.0                     NaN
# ...                    ...                     ...                     ...
# 2514261              False                     0.0                     NaN
# 2514262              False                     0.0                     NaN
# 2514263              False                     0.0                     NaN
# 2514264              False                     0.0                     NaN
# 2514265              False                     0.0                     NaN
#
#          (case) penalty_amount2  (case) penalty_amount3  (case) program-id  \
# 0                           NaN                     NaN                215
# 1                           NaN                     NaN                215
# 2                           NaN                     NaN                215
# 3                           NaN                     NaN                215
# 4                           NaN                     NaN                215
# ...                         ...                     ...                ...
# 2514261                     NaN                     NaN                215
# 2514262                     NaN                     NaN                215
# 2514263                     NaN                     NaN                215
# 2514264                     NaN                     NaN                215
# 2514265                     NaN                     NaN                215
#
#          (case) redistribution  (case) rejected  (case) risk_factor  \
# 0                         True            False                 1.0
# 1                         True            False                 1.0
# 2                         True            False                 1.0
# 3                         True            False                 1.0
# 4                         True            False                 1.0
# ...                        ...              ...                 ...
# 2514261                   True            False                 1.0
# 2514262                   True            False                 1.0
# 2514263                   True            False                 1.0
# 2514264                   True            False                 1.0
# 2514265                   True            False                 1.0
#
#          (case) selected_manually  (case) selected_random  \
# 0                           False                   False
# 1                           False                   False
# 2                           False                   False
# 3                           False                   False
# 4                           False                   False
# ...                           ...                     ...
# 2514261                     False                   False
# 2514262                     False                   False
# 2514263                     False                   False
# 2514264                     False                   False
# 2514265                     False                   False
#
#          (case) selected_risk  (case) small farmer  (case) year  \
# 0                       False                 True         2015
# 1                       False                 True         2015
# 2                       False                 True         2015
# 3                       False                 True         2015
# 4                       False                 True         2015
# ...                       ...                  ...          ...
# 2514261                 False                False         2017
# 2514262                 False                False         2017
# 2514263                 False                False         2017
# 2514264                 False                False         2017
# 2514265                 False                False         2017
#
#          (case) young farmer         activity     concept:name  \
# 0                      False      mail income      mail income
# 1                      False       mail valid       mail valid
# 2                      False       mail valid       mail valid
# 3                      False       mail valid       mail valid
# 4                      False       initialize       initialize
# ...                      ...              ...              ...
# 2514261                False           decide           decide
# 2514262                False    begin payment    begin payment
# 2514263                False  insert document  insert document
# 2514264                False  insert document  insert document
# 2514265                False   finish payment   finish payment
#
#                      docid                  doctype       eventid  \
# 0       -18008611495569447      Payment application           NaN
# 1       -18008611495569447      Payment application           NaN
# 2       -18008615298673397  Entitlement application           NaN
# 3       -18008615298673397  Entitlement application           NaN
# 4       -72051858488795160      Geo parcel document -7.205186e+16
# ...                    ...                      ...           ...
# 2514261 -54037160734808716      Payment application -9.006594e+16
# 2514262 -54037160734808716      Payment application -9.006594e+16
# 2514263 -54037160734808716      Payment application -9.006594e+16
# 2514264 -54037160734808716      Payment application -1.260947e+17
# 2514265 -54037160734808716      Payment application -1.800834e+16
#
#         lifecycle:transition                        note   subprocess  \
# 0                   complete                        none  Application
# 1                   complete                        none  Application
# 2                   complete                        none         Main
# 3                   complete                        none         Main
# 4                   complete                        none         Main
# ...                      ...                         ...          ...
# 2514261             complete                   automatic  Application
# 2514262             complete    automatic during payment  Application
# 2514263             complete  notification for applicant  Application
# 2514264             complete  notification for applicant  Application
# 2514265             complete    automatic during payment  Application
#
#          success                       Sub_Process  StartDate  \
# 0              1  Payment application, Application 2015-05-08
# 1              1  Payment application, Application 2015-05-08
# 2              1     Entitlement application, Main 2015-05-08
# 3              1     Entitlement application, Main 2015-05-08
# 4              1         Geo parcel document, Main 2015-05-08
# ...          ...                               ...        ...
# 2514261        1  Payment application, Application 2017-04-13
# 2514262        1  Payment application, Application 2017-04-13
# 2514263        1  Payment application, Application 2017-04-13
# 2514264        0  Payment application, Application 2017-04-13
# 2514265        1  Payment application, Application 2017-04-13
#
#                         EndDate  Total_Duration  TimePassed  eventcounter  \
# 0       2016-02-18 07:56:22.774             286           0             1
# 1       2016-02-18 07:56:22.774             286           0             2
# 2       2016-02-18 07:56:22.774             286           0             3
# 3       2016-02-18 07:56:22.774             286           0             4
# 4       2016-02-18 07:56:22.774             286          33             5
# ...                         ...             ...         ...           ...
# 2514261 2018-01-05 14:45:52.100             267         242            59
# 2514262 2018-01-05 14:45:52.100             267         246            60
# 2514263 2018-01-05 14:45:52.100             267         246            61
# 2514264 2018-01-05 14:45:52.100             267         251            62
# 2514265 2018-01-05 14:45:52.100             267         267            63
#
#          cum_success  succes_rate  cum_activity  cum_subprocess  Timelag  \
# 0                  1     1.000000             1               1      0.0
# 1                  2     1.000000             1               2      0.0
# 2                  3     1.000000             2               1      0.0
# 3                  4     1.000000             3               2      0.0
# 4                  5     1.000000             1               1     33.0
# ...              ...          ...           ...             ...      ...
# 2514261           59     1.000000             1              16      2.0
# 2514262           60     1.000000             1              17      4.0
# 2514263           61     1.000000             2              18      0.0
# 2514264           61     0.983871             3              19      4.0
# 2514265           62     0.984127             1              20     16.0
#
#          Max_lag   Avg_lag  avg_amount_applied0_per_parcel  \
# 0            0.0  0.000000                      320.116667
# 1            0.0  0.000000                      320.116667
# 2            0.0  0.000000                      320.116667
# 3            0.0  0.000000                      320.116667
# 4           33.0  0.000000                      320.116667
# ...          ...       ...                             ...
# 2514261     75.0  4.017241                      852.995000
# 2514262     75.0  3.983051                      852.995000
# 2514263     75.0  3.983333                      852.995000
# 2514264     75.0  3.918033                      852.995000
# 2514265     75.0  3.919355                      852.995000
#
#          avg_amount_applied0_per_area  avg_area_per_parcel StartMonth
# 0                          355.764244             0.899800        May
# 1                          355.764244             0.899800        May
# 2                          355.764244             0.899800        May
# 3                          355.764244             0.899800        May
# 4                          355.764244             0.899800        May
# ...                               ...                  ...        ...
# 2514261                    334.932529             2.546767      April
# 2514262                    334.932529             2.546767      April
# 2514263                    334.932529             2.546767      April
# 2514264                    334.932529             2.546767      April
# 2514265                    334.932529             2.546767      April
#
# [2514266 rows x 92 columns]

# %%
utils._save_pickle(df, 'dataset/final_input_for_counters')
