# %%
import pandas as pd

# %%
data = pd.read_excel('bpi_challenge_2018_50mb.xlsx')

# %%
adf = data.loc[data['Activity'] == 'Payment application-Application-abort payment']
len(adf)
# Out:
# 4291

# %%
adf = data.loc[data['Activity'] == 'Payment application-Application-begin payment']
len(adf)
# Out:
# 7291

# %%
# drop uncomplete cases (2017 mostly) and thus do not have a complete label

# %% [markdown]
# ## Undesired Outcome 1

# %% [markdown]
# Undesired outcome 1: The payment is late. A payment can be considered
# timely, if there has been a begin payment activity by the end of the year that was
# not eventually followed by abort payment.

# %% [markdown]
# Late Payments There is no easy way of filtering the cases to find cases with
# late payments. So in order to look at the differences, we added a case attribute
# ourselves with the use of Python. With the use of the ProM forum, we identified
# 3 situations in which a case is considered late:
# 1. There is no ‘begin payment’ event in the case.
# 2. The last ‘begin payment’ event is followed by an ‘abort payment’ event.
# 3. The last ‘begin payment’ event occurs in a later year than what the case was
# started in.

# %% [markdown]
# ### 1. There is no 'begin payment' event in the case

# %%
# group by per caseid --> to find latest payment

df = data.loc[data['Activity'] == 'Payment application-Application-begin payment']
df = df.rename(columns = {'Complete Timestamp': 'Timestamp'})
latest_payments = df.loc[df.groupby('Case ID').Timestamp.idxmax()]
#latest_payments.loc[latest_payments['Case ID'] == '788e3f355afbed07']
for i in latest_payments.index:
    # choose which dataframe to update
    # for now pick dataframe: data
    
    data.loc[i,'Latest_Begin_Payment'] = 1

# %%
data.tail()
# Out:
#                  Case ID                             Activity Resource  \
# 193675  4c1dce27d1fa14a5            Parcel document-Main-save   478c4f
# 193676  4c1dce27d1fa14a5           Parcel document-Main-check   478c4f
# 193677  4c1dce27d1fa14a5  Parcel document-Main-finish editing   478c4f
# 193678  4c1dce27d1fa14a5            Control summary-Main-save   478c4f
# 193679  4c1dce27d1fa14a5            Control summary-Main-save   6ad4a6
#
#        Complete Timestamp       Variant  Variant index  \
# 193675         2016-06-16  Variant 9000           9000
# 193676         2016-06-16  Variant 9000           9000
# 193677         2016-06-16  Variant 9000           9000
# 193678         2016-06-16  Variant 9000           9000
# 193679         2016-08-10  Variant 9000           9000
#
#         (case) amount_applied0  (case) amount_applied1  \
# 193675                16309.96                     NaN
# 193676                16309.96                     NaN
# 193677                16309.96                     NaN
# 193678                16309.96                     NaN
# 193679                16309.96                     NaN
#
#         (case) amount_applied2  (case) amount_applied3  ...    concept:name  \
# 193675                     NaN                     NaN  ...            save
# 193676                     NaN                     NaN  ...           check
# 193677                     NaN                     NaN  ...  finish editing
# 193678                     NaN                     NaN  ...            save
# 193679                     NaN                     NaN  ...            save
#
#                     docid          doctype       eventid  \
# 193675 -18008662613106736  Parcel document -5.403733e+16
# 193676 -18008662613106736  Parcel document -5.403733e+16
# 193677 -18008662613106736  Parcel document -5.403733e+16
# 193678 -18008662613106034  Control summary -5.403733e+16
# 193679 -18008662613106034  Control summary -3.602291e+16
#
#         lifecycle:transition  note  subprocess  success  Latest_Begin_Payment  \
# 193675              complete  none        Main     True                   NaN
# 193676              complete  none        Main     True                   NaN
# 193677              complete  none        Main     True                   NaN
# 193678              complete  none        Main     True                   NaN
# 193679              complete  none        Main     True                   NaN
#
#         Latest_Abort_Payment
# 193675                   NaN
# 193676                   NaN
# 193677                   NaN
# 193678                   NaN
# 193679                   NaN
#
# [5 rows x 77 columns]

# %%
len(data.loc[data['Latest_Begin_Payment'] == 1])
# Out:
# 3000

# %%
# find all case id's for which the sum of Latest begin payment = 0.
payments = data[['Case ID', 'Latest_Begin_Payment']].groupby(by=['Case ID']).sum()
no_begin_payment = payments.loc[payments['Latest_Begin_Payment'] == 0]

# in current subset of data there is no sensor without begin payment
no_begin_payment
# Out:
#                   Latest_Begin_Payment    index
# Case ID
# 06501822341c30a8                   0.0  4830588

# %%
for i in no_begin_payment.index:
    # for all cases without begin payment --> label them as undesired outcome rows.
    data.loc[data['Case ID'] == i, 'UndesiredOutcome1'] = 1

# %%
data.loc[data['UndesiredOutcome1'] == 1].head()
# Out:
#                  Case ID                                     Activity  \
# 166558  06501822341c30a8  Payment application-Application-mail income
# 166559  06501822341c30a8      Entitlement application-Main-mail valid
# 166560  06501822341c30a8   Payment application-Application-mail valid
# 166561  06501822341c30a8      Entitlement application-Main-mail valid
# 166562  06501822341c30a8              Parcel document-Main-initialize
#
#                              Resource Complete Timestamp       Variant  \
# 166558                          0;n/a         2015-05-10  Variant 8575
# 166559                          0;n/a         2015-05-11  Variant 8575
# 166560                          0;n/a         2015-05-11  Variant 8575
# 166561                          0;n/a         2015-05-11  Variant 8575
# 166562  Document processing automaton         2015-06-12  Variant 8575
#
#         Variant index  (case) amount_applied0  (case) amount_applied1  \
# 166558           8575                     0.0                     NaN
# 166559           8575                     0.0                     NaN
# 166560           8575                     0.0                     NaN
# 166561           8575                     0.0                     NaN
# 166562           8575                     0.0                     NaN
#
#         (case) amount_applied2  (case) amount_applied3  ...  \
# 166558                     NaN                     NaN  ...
# 166559                     NaN                     NaN  ...
# 166560                     NaN                     NaN  ...
# 166561                     NaN                     NaN  ...
# 166562                     NaN                     NaN  ...
#
#                     docid                  doctype       eventid  \
# 166558 -18008611495764646      Payment application           NaN
# 166559 -18008615298820872  Entitlement application           NaN
# 166560 -18008611495764646      Payment application           NaN
# 166561 -18008615298820872  Entitlement application           NaN
# 166562 -18008662110812216          Parcel document -1.800866e+16
#
#         lifecycle:transition  note   subprocess  success  \
# 166558              complete  none  Application     True
# 166559              complete  none         Main     True
# 166560              complete  none  Application     True
# 166561              complete  none         Main     True
# 166562              complete  none         Main     True
#
#         Latest_Begin_Payment  Latest_Abort_Payment  UndesiredOutcome1
# 166558                   NaN                   NaN                1.0
# 166559                   NaN                   NaN                1.0
# 166560                   NaN                   NaN                1.0
# 166561                   NaN                   NaN                1.0
# 166562                   NaN                   NaN                1.0
#
# [5 rows x 78 columns]

# %% [markdown]
# ### 2. The last ‘begin payment’ event is followed by an ‘abort payment’ event.

# %%
# Add column that indicates the latest abort payment 

adf = data.loc[data['Activity'] == 'Payment application-Application-abort payment']
adf = adf.rename(columns = {'Complete Timestamp': 'Timestamp'})

# Does not make sense to only take the latest abort statement? --> it does the job but
latest_aborts = adf.loc[adf.groupby('Case ID').Timestamp.idxmax()]
#latest_payments.loc[latest_payments['Case ID'] == '788e3f355afbed07']
for i in latest_aborts.index:
    
    data.loc[i,'Latest_Abort_Payment'] = 1

# %%
# insert artificial row that complies with the criteria

# %%
# filter on criteria: cases with a begin payment and an abort payment
test = data.loc[(data['Latest_Begin_Payment'] == 1) & (data['Latest_Abort_Payment'] ==1)]

# %%
# filter cases with date of abort payment activity > date of latest_begin_payment

# Each case id has at max 2 rows. This because we only consider the LATEST begin payment and LATEST abort payment

test2 = test.groupby('Case ID')['Complete Timestamp'].agg(['min','max']).rename(columns={'min':'first','max':'last'})

test3 = pd.merge(test, test2, left_on='Case ID', right_on='Case ID')


# check if timestamp of latest abort payment row  == max --> then there is an abort payment after the latest begin payment
for i in test3.index:
    
    row = test3.loc[i, :]
    
    if row['Latest_Abort_Payment'] ==1 and row['Complete Timestamp'] > row['last']: # check timestamps
        test3.loc[i, 'abort_after_begin_payment'] = 1
        
        
        
# label case as undesired outcome 1 in 'data' dataframe

# %%
test3
# Out:
# Empty DataFrame
# Columns: [Case ID, Activity, Resource, Complete Timestamp, Variant, Variant index, (case) amount_applied0, (case) amount_applied1, (case) amount_applied2, (case) amount_applied3, (case) applicant, (case) application, (case) area, (case) basic payment, (case) cross_compliance, (case) department, (case) greening, (case) number_parcels, (case) payment_actual0, (case) payment_actual1, (case) payment_actual2, (case) payment_actual3, (case) penalty_ABP, (case) penalty_AGP, (case) penalty_AJLP, (case) penalty_AUVP, (case) penalty_AVBP, (case) penalty_AVGP, (case) penalty_AVJLP, (case) penalty_AVUVP, (case) penalty_B16, (case) penalty_B2, (case) penalty_B3, (case) penalty_B4, (case) penalty_B5, (case) penalty_B5F, (case) penalty_B6, (case) penalty_BGK, (case) penalty_BGKV, (case) penalty_BGP, (case) penalty_C16, (case) penalty_C4, (case) penalty_C9, (case) penalty_CC, (case) penalty_GP1, (case) penalty_JLP1, (case) penalty_JLP2, (case) penalty_JLP3, (case) penalty_JLP5, (case) penalty_JLP6, (case) penalty_JLP7, (case) penalty_V5, (case) penalty_amount0, (case) penalty_amount1, (case) penalty_amount2, (case) penalty_amount3, (case) program-id, (case) redistribution, (case) rejected, (case) risk_factor, (case) selected_manually, (case) selected_random, (case) selected_risk, (case) small farmer, (case) year, (case) young farmer, activity, concept:name, docid, doctype, eventid, lifecycle:transition, note, subprocess, success, Latest_Begin_Payment, Latest_Abort_Payment, first, last]
# Index: []
#
# [0 rows x 79 columns]

# %%
#

# %% [markdown]
# ### 3. The last ‘begin payment’ event occurs in a later year than what the case was started in.

# %%
# determine case start year
start_years = data.groupby(by=['Case ID'])['Complete Timestamp'].agg(['min']).rename(columns={'min':'StartDate'})
start_years = start_years.reset_index()
start_years
# Out:
#                Case ID  StartDate
# 0     000612b48d30de74 2015-05-06
# 1     0032b59241ce3589 2015-04-30
# 2     0042f6f2a63d2cb6 2015-04-27
# 3     004d4aadd6785efd 2015-05-06
# 4     005e4fdaf08da672 2015-05-07
# ...                ...        ...
# 2996  ff965028d78043eb 2015-04-21
# 2997  ffe107efb55aa4c4 2015-05-12
# 2998  ffe298a47381c8b7 2015-04-18
# 2999  ffebb3a36fc7caee 2015-04-29
# 3000  fffa4b3264750002 2015-04-20
#
# [3001 rows x 2 columns]

# %%
# determine latest begin payment year
latest_begin_payment_year = data.loc[data['Activity'] == 'Payment application-Application-abort payment'].groupby(by=['Case ID'])['Complete Timestamp'].agg(['min']).rename(columns={'min':'StartDate'})
latest_begin_payment_year = latest_begin_payment_year.reset_index()
latest_begin_payment_year
# Out:
#                Case ID  StartDate
# 0     000612b48d30de74 2015-12-18
# 1     0032b59241ce3589 2015-12-18
# 2     0042f6f2a63d2cb6 2015-12-16
# 3     005e4fdaf08da672 2015-12-18
# 4     0063e4bb2015f0ba 2015-12-18
# ...                ...        ...
# 2978  ff965028d78043eb 2015-12-17
# 2979  ffe107efb55aa4c4 2015-12-18
# 2980  ffe298a47381c8b7 2015-12-16
# 2981  ffebb3a36fc7caee 2015-12-17
# 2982  fffa4b3264750002 2015-12-18
#
# [2983 rows x 2 columns]

# %%
# check if year of latest begin payment > case start year

# if true --> undesired outcome 1

# %%
# merge two dataframes

# %% [markdown]
# ## Undesired Outcome 2
